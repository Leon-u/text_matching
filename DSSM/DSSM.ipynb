# %%
from data_load import load_char_data, load_vocab
import torch
import torch.nn as nn
from torch.utils.data import DataLoader,Dataset

# %% [markdown]
# ## DSSM模型搭建

# %%
class DSSM(nn.Module):
    def __init__(self, CHAR_SIZE, embedding_size):
        super(DSSM, self).__init__()
        self.embedding=nn.Embedding(CHAR_SIZE,embedding_size)
        self.linear1=nn.Linear(embedding_size,256)
        self.linear2=nn.Linear(256,128)
        self.linear3=nn.Linear(128,64)
        self.dropout=nn.Dropout(p=0.2)
    
    def forward(self, a, b):
        a=self.embedding(a).sum(1)
        b=self.embedding(b).sum(1)
        
        a=torch.tanh(self.linear1(a))
        a=self.dropout(a)
        a=torch.tanh(self.linear2(a))
        a=self.dropout(a)
        a=torch.tanh(self.linear3(a))
        a=self.dropout(a)
        
        b=torch.tanh(self.linear1(b))
        b=self.dropout(b)
        b=torch.tanh(self.linear2(b))
        b=self.dropout(b)
        b=torch.tanh(self.linear3(b))
        b=self.dropout(b)
        
        cosine=torch.cosine_similarity(a,b,dim=1,eps=1e-8)
        return cosine
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                torch.nn.init.xavier_uniform_(m.weight)

# %% [markdown]
# 模型的一些参数，可根据实际需求增添，调整大小

# %%
EPOCH=50
BATCH_SIZE=50
LR=0.0005

# %%
CHAR_SIZE=10041
embedding_size=300

# %% [markdown]
# ## 需定义自己的数据集，模板格式如下：

# %%
class MRPCDataset(Dataset):
    def __init__(self,filepath):
        self.path=filepath
        self.a_index, self.b_index, self.label=load_char_data(filepath)
        
    def __len__(self):
        return len(self.a_index)
    
    def __getitem__(self,idx):
        return self.a_index[idx],self.b_index[idx],self.label[idx]

# %%
dev_path='./MRPC/test_data.csv'
test4test=MRPCDataset(dev_path)
test4test[10]
# Out:
# (array([ 149, 9801, 4608, 8518, 7378, 2775, 5882, 7446, 5849, 7148,  121,
#         7250, 8574, 4730, 1630, 5825, 7447, 2430, 4516, 4434, 7995,  255,
#         4320,  434, 1937,  585, 5472, 8103, 8017, 6666, 1252, 3661, 7471,
#         3210, 2680, 2135, 9330, 4277, 4307, 5804, 6718, 1370, 9089, 4350,
#         5752, 3658, 6683, 3465, 7819,   92, 7714, 7716, 1573, 8165, 7784,
#         6362, 5046, 7279, 2817,  702, 2729,  959,   92, 8011, 5479, 4369,
#         2159,  672, 2963, 2353]),
#  array([ 434, 1937, 4541, 4939,   45, 8282, 3157, 2776, 2738, 5279, 2342,
#         1215, 6617, 8283, 9138, 3932,  705, 4414, 3547, 8632,  149, 9801,
#         4608, 8518, 7378, 2775, 5882, 7446, 5849, 7148,  121, 7250, 8574,
#         4730, 4839,  433,  325, 2695, 3785,  980, 4839, 8373, 3852, 1937,
#         7279, 2817, 8909, 1370, 6723, 8103, 8017, 1370, 9089, 4350, 5752,
#         3658, 6683, 3465, 7819,   92, 7714, 7716, 1573, 8367, 6000, 5281,
#         9337, 5588, 1894, 6930]),
#  1)

# %%
data_root='./MRPC/'
train_path=data_root+'train_data.csv'
test_path=data_root+'test_data.csv'

# %%
# 创建数据集并创立数据载入器
train_data=MRPCDataset(train_path)
test_data=MRPCDataset(test_path)
tarin_loader=DataLoader(dataset=train_data, batch_size=BATCH_SIZE, shuffle=True)
test_loader=DataLoader(dataset=test_data, batch_size=BATCH_SIZE, shuffle=True)

device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
dssm=DSSM(CHAR_SIZE=CHAR_SIZE, embedding_size=embedding_size).to(device)

optimizer=torch.optim.Adam(dssm.parameters(),lr=LR)
loss_func=nn.CrossEntropyLoss()

# %%
for epoch in range(EPOCH):
    for step, (text_a, text_b, label) in enumerate(tarin_loader):
        a = text_a.to(device).long()
        b = text_b.to(device).long()
        l = torch.LongTensor(label).to(device)
        
        pos_res = dssm(a,b)
        neg_res = l-pos_res
        
        out = torch.stack([neg_res, pos_res],1).to(device)
        loss = loss_func(out,l)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if(step+1) % 20 == 0:
            total=0
            correct=0
            for (test_a, test_b, test_l) in test_loader:
                tst_a = test_a.to(device).long()
                tst_b = test_b.to(device).long()
                tst_l = torch.LongTensor(test_l).to(device)
                
                pos_res = dssm(tst_a, tst_b)
                neg_res = 1-pos_res
                out=torch.max(torch.stack([neg_res, pos_res],1).to(device), 1)[1]
                if out.size()==tst_l.size():
                    total+=tst_l.size(0)
                    correct+=(out==tst_l).sum().item()
            print('[Epoch]:',epoch+1,'训练loss',loss.item())
            print('[Epoch]:',epoch+1,'测试集准确率',(correct*1.0/total))
# Out:
# [Epoch]: 1 训练loss 0.8622357249259949
# [Epoch]: 1 测试集准确率 0.6585507246376812
# [Epoch]: 1 训练loss 0.806443989276886
# [Epoch]: 1 测试集准确率 0.6707246376811594
# [Epoch]: 1 训练loss 0.8646817207336426
# [Epoch]: 1 测试集准确率 0.6742028985507247
# [Epoch]: 1 训练loss 0.8290250897407532
# [Epoch]: 1 测试集准确率 0.6759420289855073
# [Epoch]: 2 训练loss 0.795433521270752
# [Epoch]: 2 测试集准确率 0.6840579710144927
# [Epoch]: 2 训练loss 0.7097998857498169
# [Epoch]: 2 测试集准确率 0.6747826086956522
# [Epoch]: 2 训练loss 0.7851957678794861
# [Epoch]: 2 测试集准确率 0.663768115942029
# [Epoch]: 2 训练loss 0.8129715919494629
# [Epoch]: 2 测试集准确率 0.6556521739130434
# [Epoch]: 3 训练loss 0.6672949194908142
# [Epoch]: 3 测试集准确率 0.6423188405797101
# [Epoch]: 3 训练loss 0.746493399143219
# [Epoch]: 3 测试集准确率 0.6678260869565218
# [Epoch]: 3 训练loss 0.7733408212661743
# [Epoch]: 3 测试集准确率 0.6614492753623188
# [Epoch]: 3 训练loss 0.8352243900299072
# [Epoch]: 3 测试集准确率 0.673623188405797
# [Epoch]: 4 训练loss 0.8113890886306763
# [Epoch]: 4 测试集准确率 0.64
# [Epoch]: 4 训练loss 0.7458502054214478
# [Epoch]: 4 测试集准确率 0.663768115942029
# [Epoch]: 4 训练loss 0.8003663420677185
# [Epoch]: 4 测试集准确率 0.6446376811594203
# [Epoch]: 4 训练loss 0.8052442073822021
# [Epoch]: 4 测试集准确率 0.6521739130434783
# [Epoch]: 5 训练loss 0.6804807186126709
# [Epoch]: 5 测试集准确率 0.6405797101449275
# [Epoch]: 5 训练loss 0.6838544607162476
# [Epoch]: 5 测试集准确率 0.6533333333333333
# [Epoch]: 5 训练loss 0.678969144821167
# [Epoch]: 5 测试集准确率 0.6533333333333333
# [Epoch]: 5 训练loss 0.7284162044525146
# [Epoch]: 5 测试集准确率 0.6568115942028986
# [Epoch]: 6 训练loss 0.6514413356781006
# [Epoch]: 6 测试集准确率 0.6405797101449275
# [Epoch]: 6 训练loss 0.6522164940834045
# [Epoch]: 6 测试集准确率 0.6527536231884058
# [Epoch]: 6 训练loss 0.726421058177948
# [Epoch]: 6 测试集准确率 0.6510144927536232
# [Epoch]: 6 训练loss 0.5926246047019958
# [Epoch]: 6 测试集准确率 0.6318840579710145
# [Epoch]: 7 训练loss 0.5806573033332825
# [Epoch]: 7 测试集准确率 0.6278260869565218
# [Epoch]: 7 训练loss 0.6043756604194641
# [Epoch]: 7 测试集准确率 0.6394202898550725
# [Epoch]: 7 训练loss 0.6563453078269958
# [Epoch]: 7 测试集准确率 0.6515942028985507
# [Epoch]: 7 训练loss 0.7050023674964905
# [Epoch]: 7 测试集准确率 0.6434782608695652
# [Epoch]: 8 训练loss 0.5714247226715088
# [Epoch]: 8 测试集准确率 0.6295652173913043
# [Epoch]: 8 训练loss 0.6597349047660828
# [Epoch]: 8 测试集准确率 0.6313043478260869
# [Epoch]: 8 训练loss 0.5621588230133057
# [Epoch]: 8 测试集准确率 0.6498550724637682
# [Epoch]: 8 训练loss 0.5784693360328674
# [Epoch]: 8 测试集准确率 0.6417391304347826
# [Epoch]: 9 训练loss 0.5496249198913574
# [Epoch]: 9 测试集准确率 0.6394202898550725
# [Epoch]: 9 训练loss 0.5072305798530579
# [Epoch]: 9 测试集准确率 0.6110144927536232
# [Epoch]: 9 训练loss 0.5643371343612671
# [Epoch]: 9 测试集准确率 0.6463768115942029
# [Epoch]: 9 训练loss 0.6151753664016724
# [Epoch]: 9 测试集准确率 0.6446376811594203
# [Epoch]: 10 训练loss 0.6644641757011414
# [Epoch]: 10 测试集准确率 0.6376811594202898
# [Epoch]: 10 训练loss 0.5949528217315674
# [Epoch]: 10 测试集准确率 0.6313043478260869
# [Epoch]: 10 训练loss 0.600917637348175
# [Epoch]: 10 测试集准确率 0.6481159420289855
# [Epoch]: 10 训练loss 0.6400898098945618
# [Epoch]: 10 测试集准确率 0.6330434782608696
# [Epoch]: 11 训练loss 0.5448266863822937
# [Epoch]: 11 测试集准确率 0.6452173913043479
# [Epoch]: 11 训练loss 0.5843657851219177
# [Epoch]: 11 测试集准确率 0.6417391304347826
# [Epoch]: 11 训练loss 0.5598494410514832
# [Epoch]: 11 测试集准确率 0.6376811594202898
# [Epoch]: 11 训练loss 0.5869652628898621
# [Epoch]: 11 测试集准确率 0.6469565217391304
# [Epoch]: 12 训练loss 0.5144967436790466
# [Epoch]: 12 测试集准确率 0.6365217391304347
# [Epoch]: 12 训练loss 0.6150928735733032
# [Epoch]: 12 测试集准确率 0.6405797101449275
# [Epoch]: 12 训练loss 0.5203359723091125
# [Epoch]: 12 测试集准确率 0.6266666666666667
# [Epoch]: 12 训练loss 0.466507226228714
# [Epoch]: 12 测试集准确率 0.648695652173913
# [Epoch]: 13 训练loss 0.5340514183044434
# [Epoch]: 13 测试集准确率 0.6365217391304347
# [Epoch]: 13 训练loss 0.5795690417289734
# [Epoch]: 13 测试集准确率 0.6463768115942029
# [Epoch]: 13 训练loss 0.5211061835289001
# [Epoch]: 13 测试集准确率 0.6220289855072464
# [Epoch]: 13 训练loss 0.5182110071182251
# [Epoch]: 13 测试集准确率 0.6446376811594203
# [Epoch]: 14 训练loss 0.44123753905296326
# [Epoch]: 14 测试集准确率 0.6434782608695652
# [Epoch]: 14 训练loss 0.5665245056152344
# [Epoch]: 14 测试集准确率 0.6457971014492754
# [Epoch]: 14 训练loss 0.5838659405708313
# [Epoch]: 14 测试集准确率 0.6515942028985507
# [Epoch]: 14 训练loss 0.5682418346405029
# [Epoch]: 14 测试集准确率 0.64
# [Epoch]: 15 训练loss 0.43711134791374207
# [Epoch]: 15 测试集准确率 0.6353623188405797
# [Epoch]: 15 训练loss 0.5197353363037109
# [Epoch]: 15 测试集准确率 0.6318840579710145
# [Epoch]: 15 训练loss 0.46641767024993896
# [Epoch]: 15 测试集准确率 0.6307246376811594
# [Epoch]: 15 训练loss 0.5100230574607849
# [Epoch]: 15 测试集准确率 0.6504347826086957
# [Epoch]: 16 训练loss 0.46217018365859985
# [Epoch]: 16 测试集准确率 0.6185507246376811
# [Epoch]: 16 训练loss 0.44464102387428284
# [Epoch]: 16 测试集准确率 0.6324637681159421
# [Epoch]: 16 训练loss 0.4367259740829468
# [Epoch]: 16 测试集准确率 0.6463768115942029
# [Epoch]: 16 训练loss 0.48205921053886414
# [Epoch]: 16 测试集准确率 0.6428985507246376
# [Epoch]: 17 训练loss 0.42261287569999695
# [Epoch]: 17 测试集准确率 0.6359420289855072
# [Epoch]: 17 训练loss 0.44781723618507385
# [Epoch]: 17 测试集准确率 0.6260869565217392
# [Epoch]: 17 训练loss 0.5524408221244812
# [Epoch]: 17 测试集准确率 0.6278260869565218
# [Epoch]: 17 训练loss 0.48039400577545166
# [Epoch]: 17 测试集准确率 0.6359420289855072
# [Epoch]: 18 训练loss 0.5131765604019165
# [Epoch]: 18 测试集准确率 0.6336231884057971
# [Epoch]: 18 训练loss 0.4511127173900604
# [Epoch]: 18 测试集准确率 0.638840579710145
# [Epoch]: 18 训练loss 0.47978079319000244
# [Epoch]: 18 测试集准确率 0.638840579710145
# [Epoch]: 18 训练loss 0.44597163796424866
# [Epoch]: 18 测试集准确率 0.6173913043478261
# [Epoch]: 19 训练loss 0.5045152902603149
# [Epoch]: 19 测试集准确率 0.6417391304347826
# [Epoch]: 19 训练loss 0.48673638701438904
# [Epoch]: 19 测试集准确率 0.6324637681159421
# [Epoch]: 19 训练loss 0.539516270160675
# [Epoch]: 19 测试集准确率 0.6260869565217392
# [Epoch]: 19 训练loss 0.473102331161499
# [Epoch]: 19 测试集准确率 0.6359420289855072
# [Epoch]: 20 训练loss 0.44898471236228943
# [Epoch]: 20 测试集准确率 0.6342028985507246
# [Epoch]: 20 训练loss 0.4463944137096405
# [Epoch]: 20 测试集准确率 0.624927536231884
# [Epoch]: 20 训练loss 0.48382866382598877
# [Epoch]: 20 测试集准确率 0.6243478260869565
# [Epoch]: 20 训练loss 0.4970514178276062
# [Epoch]: 20 测试集准确率 0.6330434782608696
# [Epoch]: 21 训练loss 0.48971226811408997
# [Epoch]: 21 测试集准确率 0.6324637681159421
# [Epoch]: 21 训练loss 0.4571925699710846
# [Epoch]: 21 测试集准确率 0.6208695652173913
# [Epoch]: 21 训练loss 0.4469406008720398
# [Epoch]: 21 测试集准确率 0.6289855072463768
# [Epoch]: 21 训练loss 0.5138840675354004
# [Epoch]: 21 测试集准确率 0.6330434782608696
# [Epoch]: 22 训练loss 0.5092056393623352
# [Epoch]: 22 测试集准确率 0.6498550724637682
# [Epoch]: 22 训练loss 0.5281214118003845
# [Epoch]: 22 测试集准确率 0.64
# [Epoch]: 22 训练loss 0.48974430561065674
# [Epoch]: 22 测试集准确率 0.6318840579710145
# [Epoch]: 22 训练loss 0.44240057468414307
# [Epoch]: 22 测试集准确率 0.6347826086956522
# [Epoch]: 23 训练loss 0.48002758622169495
# [Epoch]: 23 测试集准确率 0.6446376811594203
# [Epoch]: 23 训练loss 0.4075853228569031
# [Epoch]: 23 测试集准确率 0.6492753623188405
# [Epoch]: 23 训练loss 0.4222756624221802
# [Epoch]: 23 测试集准确率 0.6492753623188405
# [Epoch]: 23 训练loss 0.3824562132358551
# [Epoch]: 23 测试集准确率 0.6214492753623189
# [Epoch]: 24 训练loss 0.4550205171108246
# [Epoch]: 24 测试集准确率 0.6568115942028986
# [Epoch]: 24 训练loss 0.39009034633636475
# [Epoch]: 24 测试集准确率 0.6139130434782609
# [Epoch]: 24 训练loss 0.44346165657043457
# [Epoch]: 24 测试集准确率 0.6452173913043479
# [Epoch]: 24 训练loss 0.41407841444015503
# [Epoch]: 24 测试集准确率 0.6591304347826087
# [Epoch]: 25 训练loss 0.4020673632621765
# [Epoch]: 25 测试集准确率 0.6208695652173913
# [Epoch]: 25 训练loss 0.4890355169773102
# [Epoch]: 25 测试集准确率 0.6336231884057971
# [Epoch]: 25 训练loss 0.4004550576210022
# [Epoch]: 25 测试集准确率 0.6382608695652174
# [Epoch]: 25 训练loss 0.46735331416130066
# [Epoch]: 25 测试集准确率 0.6359420289855072
# [Epoch]: 26 训练loss 0.44821321964263916
# [Epoch]: 26 测试集准确率 0.6411594202898551
# [Epoch]: 26 训练loss 0.3980370759963989
# [Epoch]: 26 测试集准确率 0.6255072463768115
# [Epoch]: 26 训练loss 0.45647338032722473
# [Epoch]: 26 测试集准确率 0.6272463768115942
# [Epoch]: 26 训练loss 0.531940221786499
# [Epoch]: 26 测试集准确率 0.6423188405797101
# [Epoch]: 27 训练loss 0.4434274435043335
# [Epoch]: 27 测试集准确率 0.6226086956521739
# [Epoch]: 27 训练loss 0.4406506419181824
# [Epoch]: 27 测试集准确率 0.6260869565217392
# [Epoch]: 27 训练loss 0.4389709234237671
# [Epoch]: 27 测试集准确率 0.6353623188405797
# [Epoch]: 27 训练loss 0.5153000950813293
# [Epoch]: 27 测试集准确率 0.6457971014492754
# [Epoch]: 28 训练loss 0.49158531427383423
# [Epoch]: 28 测试集准确率 0.6498550724637682
# [Epoch]: 28 训练loss 0.4815632104873657
# [Epoch]: 28 测试集准确率 0.6318840579710145
# [Epoch]: 28 训练loss 0.375754714012146
# [Epoch]: 28 测试集准确率 0.6295652173913043
# [Epoch]: 28 训练loss 0.4540126323699951
# [Epoch]: 28 测试集准确率 0.6185507246376811
# [Epoch]: 29 训练loss 0.46712660789489746
# [Epoch]: 29 测试集准确率 0.6452173913043479
# [Epoch]: 29 训练loss 0.4109412133693695
# [Epoch]: 29 测试集准确率 0.6324637681159421
# [Epoch]: 29 训练loss 0.42340928316116333
# [Epoch]: 29 测试集准确率 0.6411594202898551
# [Epoch]: 29 训练loss 0.4350065290927887
# [Epoch]: 29 测试集准确率 0.6365217391304347
# [Epoch]: 30 训练loss 0.48754069209098816
# [Epoch]: 30 测试集准确率 0.6365217391304347
# [Epoch]: 30 训练loss 0.3937561511993408
# [Epoch]: 30 测试集准确率 0.647536231884058
# [Epoch]: 30 训练loss 0.4726126492023468
# [Epoch]: 30 测试集准确率 0.6307246376811594
# [Epoch]: 30 训练loss 0.42946183681488037
# [Epoch]: 30 测试集准确率 0.6307246376811594
# [Epoch]: 31 训练loss 0.5526639223098755
# [Epoch]: 31 测试集准确率 0.624927536231884
# [Epoch]: 31 训练loss 0.48910513520240784
# [Epoch]: 31 测试集准确率 0.6330434782608696
# [Epoch]: 31 训练loss 0.39372554421424866
# [Epoch]: 31 测试集准确率 0.6394202898550725
# [Epoch]: 31 训练loss 0.41590675711631775
# [Epoch]: 31 测试集准确率 0.6324637681159421
# [Epoch]: 32 训练loss 0.43918776512145996
# [Epoch]: 32 测试集准确率 0.6405797101449275
# [Epoch]: 32 训练loss 0.5609526634216309
# [Epoch]: 32 测试集准确率 0.624927536231884
# [Epoch]: 32 训练loss 0.4553879499435425
# [Epoch]: 32 测试集准确率 0.6289855072463768
# [Epoch]: 32 训练loss 0.4411115348339081
# [Epoch]: 32 测试集准确率 0.6139130434782609
# [Epoch]: 33 训练loss 0.47816818952560425
# [Epoch]: 33 测试集准确率 0.6359420289855072
# [Epoch]: 33 训练loss 0.47956204414367676
# [Epoch]: 33 测试集准确率 0.615072463768116
# [Epoch]: 33 训练loss 0.45150214433670044
# [Epoch]: 33 测试集准确率 0.624927536231884
# [Epoch]: 33 训练loss 0.4182971715927124
# [Epoch]: 33 测试集准确率 0.6336231884057971
# [Epoch]: 34 训练loss 0.43337082862854004
# [Epoch]: 34 测试集准确率 0.6376811594202898
# [Epoch]: 34 训练loss 0.44001346826553345
# [Epoch]: 34 测试集准确率 0.6411594202898551
# [Epoch]: 34 训练loss 0.42618778347969055
# [Epoch]: 34 测试集准确率 0.6278260869565218
# [Epoch]: 34 训练loss 0.4810730218887329
# [Epoch]: 34 测试集准确率 0.6428985507246376
# [Epoch]: 35 训练loss 0.40276843309402466
# [Epoch]: 35 测试集准确率 0.6260869565217392
# [Epoch]: 35 训练loss 0.4134451150894165
# [Epoch]: 35 测试集准确率 0.638840579710145
# [Epoch]: 35 训练loss 0.3842058479785919
# [Epoch]: 35 测试集准确率 0.6307246376811594
# [Epoch]: 35 训练loss 0.4528692662715912
# [Epoch]: 35 测试集准确率 0.6220289855072464
# [Epoch]: 36 训练loss 0.49792739748954773
# [Epoch]: 36 测试集准确率 0.6440579710144928
# [Epoch]: 36 训练loss 0.4662724435329437
# [Epoch]: 36 测试集准确率 0.6336231884057971
# [Epoch]: 36 训练loss 0.4661090075969696
# [Epoch]: 36 测试集准确率 0.6220289855072464
# [Epoch]: 36 训练loss 0.4445727467536926
# [Epoch]: 36 测试集准确率 0.6289855072463768
# [Epoch]: 37 训练loss 0.4915352165699005
# [Epoch]: 37 测试集准确率 0.6202898550724638
# [Epoch]: 37 训练loss 0.42488422989845276
# [Epoch]: 37 测试集准确率 0.6127536231884058
# [Epoch]: 37 训练loss 0.4468008875846863
# [Epoch]: 37 测试集准确率 0.6498550724637682
# [Epoch]: 37 训练loss 0.42052027583122253
# [Epoch]: 37 测试集准确率 0.6243478260869565
# [Epoch]: 38 训练loss 0.4212731122970581
# [Epoch]: 38 测试集准确率 0.6405797101449275
# [Epoch]: 38 训练loss 0.4236214756965637
# [Epoch]: 38 测试集准确率 0.6289855072463768
# [Epoch]: 38 训练loss 0.37427112460136414
# [Epoch]: 38 测试集准确率 0.615072463768116
# [Epoch]: 38 训练loss 0.47193679213523865
# [Epoch]: 38 测试集准确率 0.6411594202898551
# [Epoch]: 39 训练loss 0.46702277660369873
# [Epoch]: 39 测试集准确率 0.6394202898550725
# [Epoch]: 39 训练loss 0.4781452417373657
# [Epoch]: 39 测试集准确率 0.624927536231884
# [Epoch]: 39 训练loss 0.4499225616455078
# [Epoch]: 39 测试集准确率 0.6371014492753623
# [Epoch]: 39 训练loss 0.5188347101211548
# [Epoch]: 39 测试集准确率 0.6307246376811594
# [Epoch]: 40 训练loss 0.44844093918800354
# [Epoch]: 40 测试集准确率 0.6336231884057971
# [Epoch]: 40 训练loss 0.4745979607105255
# [Epoch]: 40 测试集准确率 0.6133333333333333
# [Epoch]: 40 训练loss 0.44558432698249817
# [Epoch]: 40 测试集准确率 0.6365217391304347
# [Epoch]: 40 训练loss 0.46652573347091675
# [Epoch]: 40 测试集准确率 0.6371014492753623
# [Epoch]: 41 训练loss 0.44946902990341187
# [Epoch]: 41 测试集准确率 0.64
# [Epoch]: 41 训练loss 0.4190521240234375
# [Epoch]: 41 测试集准确率 0.6202898550724638
# [Epoch]: 41 训练loss 0.4312289357185364
# [Epoch]: 41 测试集准确率 0.6284057971014493
# [Epoch]: 41 训练loss 0.4473515748977661
# [Epoch]: 41 测试集准确率 0.6394202898550725
# [Epoch]: 42 训练loss 0.5086557865142822
# [Epoch]: 42 测试集准确率 0.6185507246376811
# [Epoch]: 42 训练loss 0.4229080080986023
# [Epoch]: 42 测试集准确率 0.6411594202898551
# [Epoch]: 42 训练loss 0.4235275685787201
# [Epoch]: 42 测试集准确率 0.6481159420289855
# [Epoch]: 42 训练loss 0.44899001717567444
# [Epoch]: 42 测试集准确率 0.6394202898550725
# [Epoch]: 43 训练loss 0.40359175205230713
# [Epoch]: 43 测试集准确率 0.6324637681159421
# [Epoch]: 43 训练loss 0.40843236446380615
# [Epoch]: 43 测试集准确率 0.6324637681159421
# [Epoch]: 43 训练loss 0.40614432096481323
# [Epoch]: 43 测试集准确率 0.6347826086956522
# [Epoch]: 43 训练loss 0.46545174717903137
# [Epoch]: 43 测试集准确率 0.6307246376811594
# [Epoch]: 44 训练loss 0.4720379710197449
# [Epoch]: 44 测试集准确率 0.6440579710144928
# [Epoch]: 44 训练loss 0.3705701529979706
# [Epoch]: 44 测试集准确率 0.6313043478260869
# [Epoch]: 44 训练loss 0.43137839436531067
# [Epoch]: 44 测试集准确率 0.6452173913043479
# [Epoch]: 44 训练loss 0.3971877694129944
# [Epoch]: 44 测试集准确率 0.6278260869565218
# [Epoch]: 45 训练loss 0.4294669032096863
# [Epoch]: 45 测试集准确率 0.6371014492753623
# [Epoch]: 45 训练loss 0.4048425555229187
# [Epoch]: 45 测试集准确率 0.6417391304347826
# [Epoch]: 45 训练loss 0.40844258666038513
# [Epoch]: 45 测试集准确率 0.6208695652173913
# [Epoch]: 45 训练loss 0.3978036642074585
# [Epoch]: 45 测试集准确率 0.64
# [Epoch]: 46 训练loss 0.4779214560985565
# [Epoch]: 46 测试集准确率 0.6284057971014493
# [Epoch]: 46 训练loss 0.36826491355895996
# [Epoch]: 46 测试集准确率 0.6411594202898551
# [Epoch]: 46 训练loss 0.39097756147384644
# [Epoch]: 46 测试集准确率 0.6139130434782609
# [Epoch]: 46 训练loss 0.40295761823654175
# [Epoch]: 46 测试集准确率 0.6405797101449275
# [Epoch]: 47 训练loss 0.3991764783859253
# [Epoch]: 47 测试集准确率 0.6214492753623189
# [Epoch]: 47 训练loss 0.4486689865589142
# [Epoch]: 47 测试集准确率 0.6278260869565218
# [Epoch]: 47 训练loss 0.49382179975509644
# [Epoch]: 47 测试集准确率 0.6371014492753623
# [Epoch]: 47 训练loss 0.476028174161911
# [Epoch]: 47 测试集准确率 0.64
# [Epoch]: 48 训练loss 0.40883082151412964
# [Epoch]: 48 测试集准确率 0.6405797101449275
# [Epoch]: 48 训练loss 0.44437694549560547
# [Epoch]: 48 测试集准确率 0.6046376811594203
# [Epoch]: 48 训练loss 0.4315156638622284
# [Epoch]: 48 测试集准确率 0.6185507246376811
# [Epoch]: 48 训练loss 0.43039563298225403
# [Epoch]: 48 测试集准确率 0.6139130434782609
# [Epoch]: 49 训练loss 0.4182775914669037
# [Epoch]: 49 测试集准确率 0.6347826086956522
# [Epoch]: 49 训练loss 0.45249149203300476
# [Epoch]: 49 测试集准确率 0.6255072463768115
# [Epoch]: 49 训练loss 0.4578973054885864
# [Epoch]: 49 测试集准确率 0.624927536231884
# [Epoch]: 49 训练loss 0.42350247502326965
# [Epoch]: 49 测试集准确率 0.6446376811594203
# [Epoch]: 50 训练loss 0.42322781682014465
# [Epoch]: 50 测试集准确率 0.6376811594202898
# [Epoch]: 50 训练loss 0.3651021122932434
# [Epoch]: 50 测试集准确率 0.638840579710145
# [Epoch]: 50 训练loss 0.472403883934021
# [Epoch]: 50 测试集准确率 0.6220289855072464
# [Epoch]: 50 训练loss 0.3788052499294281
# [Epoch]: 50 测试集准确率 0.6359420289855072

# %%
torch.save(dssm,'./dssm.pkl')

# %%
if __name__ == '__main__':
    test_data=MRPCDataset(test_path)
    test_loader=DataLoader(dataset=test_data,batch_size=BATCH_SIZE,shuffle=False)
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    dssm = torch.load('./dssm.pkl').to(device)
    
    total=0
    correct=0
    TP, TN, FP, FN = 0, 0, 0, 0
    FLAG=True
    for (test_a, test_b, test_l) in test_loader:
        tst_a = test_a.to(device).long()
        tst_b = test_b.to(device).long()
        tst_l = torch.LongTensor(test_l).to(device)

        pos_res = dssm(tst_a, tst_b)
        neg_res = 1 - pos_res
        out = torch.max(torch.stack([neg_res, pos_res], 1).to(device), dim=1)[1]

        total += tst_l.size(0)
        correct += (out == tst_l).sum().item()

        #计算精确率、召回率
        TP += ((out == 1) & (tst_l == 1)).sum().item()
        TN += ((out == 0) & (tst_l == 0)).sum().item()
        FN += ((out == 0) & (tst_l == 1)).sum().item()
        FP += ((out == 1) & (tst_l == 0)).sum().item()

        if FLAG == True:
            for i in range(30,40):
                a, b, l = test_data[i][0], test_data[i][1], test_data[i][2]
                print('标签：',l,'预测：',out[i].item())
        FLAG=False

    p = TP / (TP + FP)
    r = TP / (TP + FN)

    print('测试集准确率: ', (correct * 1.0 / total))
    print('测试集精确率：', p)
    print('测试集召回率：', r)
    print('测试集f1-score：', 2 * r * p / (r + p))
# Out:
# 标签： 1 预测： 1
# 标签： 0 预测： 1
# 标签： 0 预测： 1
# 标签： 0 预测： 1
# 标签： 1 预测： 1
# 标签： 0 预测： 1
# 标签： 1 预测： 0
# 标签： 1 预测： 0
# 标签： 0 预测： 1
# 标签： 1 预测： 1
# 测试集准确率:  0.6208695652173913
# 测试集精确率： 0.7126833477135461
# 测试集召回率： 0.7201394943330427
# 测试集f1-score： 0.7163920208152647
