# %% [markdown]
# # 词表生成模块
# 目标：给每个 n-gram 切片 一个独有的索引id

# %%
def n_gram(word, n=3):
    s = []
    word = '#'+word+'#'
    for i in range(len(word)-(n-1)):
        s.append(word[i:i+3])
    return s

print(n_gram("keyboardkeyboard"))

def lst_gram(lst, n=3):
    s = []
    for word in str(lst).lower().split():
        s.extend(n_gram(word))
    return s

print(lst_gram("Two young children in blue jerseys"))
# Out:
# ['#ke', 'key', 'eyb', 'ybo', 'boa', 'oar', 'ard', 'rdk', 'dke', 'key', 'eyb', 'ybo', 'boa', 'oar', 'ard', 'rd#']
# ['#tw', 'two', 'wo#', '#yo', 'you', 'oun', 'ung', 'ng#', '#ch', 'chi', 'hil', 'ild', 'ldr', 'dre', 'ren', 'en#', '#in', 'in#', '#bl', 'blu', 'lue', 'ue#', '#je', 'jer', 'ers', 'rse', 'sey', 'eys', 'ys#']

# %% [markdown]
# # 读取文件
# 遍历文件中出现的每一个词，将其转化为n-gram切片后加入列表

# %%
vocab = []

# %%
file_path = "./MRPC/"
files = ["train_data.csv", "test_data.csv"]

for file in files:
    f = open(file_path+file, encoding='utf-8').readlines()
    for i in range(1, len(f)):
        s1, s2 = f[i][2:].strip('\n').split('\t')
        #对每一行，去掉前两个字符（标签（0，1，2）TAB键）
        #去掉末尾换行符，用TAB键切分字符串，刚好切为两个句子
        vocab.extend(lst_gram(s1))
        vocab.extend(lst_gram(s2))

# %%
vocab = set(vocab)
print(vocab)
# Out:
# {'#3{', 'mo#', '$a9', 'egy', 'tib', 'tun', 'ghu', '87.', 'rbo', '0-k', 'io-', '280', 'tz.', 'nz#', 'fis', '.8b', 'izz', 'opy', 'ihu', '#$2', 'ngh', 'mgm', '506', '#a.', 'ues', 'orc', 'pud', 'dsw', '3-9', 'ty]', 'yki', 't--', '620', '#mm', 'au#', 'nse', '861', 'jem', '#.8', '(rp', 'h/t', 'rui', 'g/d', 'so#', 'mir', 'h-l', 's--', '#5#', '#nl', '14%', 'ipa', '$12', 'no.', '-bo', 'mpg', 'ecb', 'mge', '425', '071', 'mkh', 'arm', 'txu', '‘‘t', 'sql', '#ya', '#n.', '1-b', '1.4', 'uot', 'i-#', '0-8', 'cky', 'ump', 'mse', 'iwa', '#od', '-9#', 'itn', 'ieb', 'shi', '#17', 'inj', 'px2', 'goo', 'qar', 'twe', '395', '26%', 'rn.', 'dec', '18.', 'gy-', 'olt', '01#', '0.4', 'alw', 'im.', 'peg', 'ud.', 'usm', '#77', 'tbu', 'uai', 'ge-', '9.7', '`in', 'l-e', '-am', 'opi', 'xcl', 'aeo', 'zi.', '12%', '$68', 'xu#', '#60', 'llm', '65.', 'okl', 'o-o', '#ro', 'ke.', '764', 'ler', 'iat', 'hud', 'oxi', 'era', 'sug', '(ko', 'kfo', 'g..', 'rón', 'o-1', 'adf', 'kop', 'are', 'alp', 'gsa', 'awm', '0-o', 'pf#', 'rdn', 'nck', '#ou', 'ulo', 'ct.', 'tei', 'ggl', 'l-w', 'kic', '4k#', 'act', '#xs', '615', '(ho', '@de', '#$9', 'zue', 'bi#', 'snu', 'rsw', 'aq.', 'hz#', '8.4', '405', '315', 'bir', '-ho', '-41', '-2#', 'syl', 'maz', '826', 'ufi', 'why', 'mpa', '4.#', '#p.', 'tt.', 'wre', '897', '(11', '929', 'ak.', 'am#', 'vik', 'ctl', 'hoa', '5.7', 'moi', '#pn', '-br', 'fry', 'edt', 'zur', '#.2', 'etm', 'obt', 'aq#', '-19', 'pic', '(tw', 'wto', 'ghw', '.9%', 'a-y', 'usa', 'onr', 'vau', 'n-t', 'ipw', 'dso', 'ynt', '8/2', 'oy’', '.dj', 'rsy', '-ol', 'ziv', 'alv', 'nr#', 'erf', 'cgr', 'tou', 'ele', 'gah', '#(f', 'dr.', 'unk', 'rpe', '80s', 'iby', 'bho', 'rei', 'itu', 'rak', 'veh', '#34', '699', 'nef', 'n.j', '389', 'y.u', 'htw', 'skt', 'guo', 'bar', 'dja', '#bi', 're’', 'd-1', '256', 'sus', '09.', 'ad-', 'o/y', 'sep', 'sni', 'd=>', 'ebv', 'f-s', 'owi', 'n-m', 'dcs', 'gt#', '7.7', 'oya', '#ew', 'wi#', '2yt', 'emu', 'tc.', 'dez', 'r-w', 'nli', 'fsk', 'kno', 'cai', '$50', 'vos', 'mph', 'noc', 'kon', 'pnc', 'j.p', 'pho', '#(7', 'ckb', '9-y', 'ir.', 'nac', 'kyo', '052', 'esp', 'occ', 'aiw', '694', 'wra', '8%.', 'krc', '74t', 'paa', '.tu', 'mud', 'iow', 'sub', 'amh', '4am', ').#', 'omb', 'oer', 'swe', '1pc', 'awa', '-be', 'saf', 'c.j', '#pu', '459', '119', 'ebi', 'kob', '#4a', 'f-o', 'ba.', 'anw', 'ghi', '.op', 'nkl', '-15', 'mcn', '306', '6.5', '-du', 'afl', 'l].', 'ffe', '.1#', 'rkn', '+j#', '#mg', 'sek', '300', '#[b', 'moc', '#c.', '390', 'lyn', '434', 'e/p', 'fia', 'phl', 'gfu', '3%)', 'agd', 'acc', 'geb', 'udu', 'ndb', 'noo', 'ccu', '#&#', '#fc', '#78', 'stm', 'lfl', '#$u', '#26', 'omf', '$65', 'hha', 'kam', 'ngo', 'rof', 's36', 'n22', 'nun', 'ejo', 'ui#', '.9-', '`br', 'ncz', 'f.#', '#c$', 'gum', 'ubg', 'ia’', '#fj', 'ued', '31-', 'sba', 'uzi', '2-9', '$18', '#57', '#.c', 'r’s', 'zha', '01.', 'osi', 'bam', '-ta', 'ewd', 'lty', 'tar', 'y.)', 'xif', '#14', 'ree', 'rts', '$17', '$23', 'rac', '262', 'uic', 'anl', 'tot', '979', '147', '628', '[ia', 'tti', 'eha', '#1p', 'hoi', '/4p', 'jis', '`on', '#h.', 'pep', 'cke', '45-', '$24', 'bao', 'pse', 'cst', '—de', 'gym', 'p.s', 'fli', '.02', 's51', 'doc', '-s#', 'bay', 'x.o', 'rix', 'bps', 'i-p', 'ths', 'bne', 'rtn', 'ga#', 'for', 'ii.', 'hci', 'ha#', 'a.g', '#--', '293', '#8#', 'f=#', 'zet', 'fev', 'mt#', 'njo', 'aso', 'rdr', 'niy', 'eza', 'rox', 'uda', 'x>#', 'b-i', 'k-l', '“7t', 'rnp', 'dri', '20s', 'soh', 'xp#', '#mt', '798', 'ke-', 'won', '#gy', 'azz', 'nth', 'iu#', '#cy', 'zab', '“sp', '#lp', 'bn.', 'jiu', 'ca#', 'fo#', '#sf', 'oa#', 'yn)', 'dae', '58.', 'luh', 'yie', 'iag', '068', 'oes', 'nb#', 'zol', '3.4', 'me-', 'oob', 'nor', '#nu', 't-g', 'ogn', 'vri', '/82', '#£9', 'ull', 'hp-', 'km#', 'spo', 'gti', 'npi', '54#', 'ak#', 'pit', 'iji', '#re', 'ddl', '225', 'nlc', 'awk', 'hoe', 'kct', '65-', 'ilp', '$15', '0-p', '#s.', '#-t', 'wls', 'atc', 'gen', 'yto', '`sl', 'ur=', 'hon', 'ciz', 'fus', 'otz', 'i>#', 'aeu', 'urg', 'wf#', 'fat', 'ozo', '-vl', 'ony', '773', 'cal', 'g+j', 'ary', 'sp2', '774', 'yno', '$80', 'emo', 'ts]', 'h ...

# %%
vocab_list = ['[PAD]','[UNK]']
vocab_list.extend(list(vocab))

# %%
list(vocab_list)
# Out:
# ['[PAD]',
#  '[UNK]',
#  '#3{',
#  'mo#',
#  '$a9',
#  'egy',
#  'tib',
#  'tun',
#  'ghu',
#  '87.',
#  'rbo',
#  '0-k',
#  'io-',
#  '280',
#  'tz.',
#  'nz#',
#  'fis',
#  '.8b',
#  'izz',
#  'opy',
#  'ihu',
#  '#$2',
#  'ngh',
#  'mgm',
#  '506',
#  '#a.',
#  'ues',
#  'orc',
#  'pud',
#  'dsw',
#  '3-9',
#  'ty]',
#  'yki',
#  't--',
#  '620',
#  '#mm',
#  'au#',
#  'nse',
#  '861',
#  'jem',
#  '#.8',
#  '(rp',
#  'h/t',
#  'rui',
#  'g/d',
#  'so#',
#  'mir',
#  'h-l',
#  's--',
#  '#5#',
#  '#nl',
#  '14%',
#  'ipa',
#  '$12',
#  'no.',
#  '-bo',
#  'mpg',
#  'ecb',
#  'mge',
#  '425',
#  '071',
#  'mkh',
#  'arm',
#  'txu',
#  '‘‘t',
#  'sql',
#  '#ya',
#  '#n.',
#  '1-b',
#  '1.4',
#  'uot',
#  'i-#',
#  '0-8',
#  'cky',
#  'ump',
#  'mse',
#  'iwa',
#  '#od',
#  '-9#',
#  'itn',
#  'ieb',
#  'shi',
#  '#17',
#  'inj',
#  'px2',
#  'goo',
#  'qar',
#  'twe',
#  '395',
#  '26%',
#  'rn.',
#  'dec',
#  '18.',
#  'gy-',
#  'olt',
#  '01#',
#  '0.4',
#  'alw',
#  'im.',
#  'peg',
#  'ud.',
#  'usm',
#  '#77',
#  'tbu',
#  'uai',
#  'ge-',
#  '9.7',
#  '`in',
#  'l-e',
#  '-am',
#  'opi',
#  'xcl',
#  'aeo',
#  'zi.',
#  '12%',
#  '$68',
#  'xu#',
#  '#60',
#  'llm',
#  '65.',
#  'okl',
#  'o-o',
#  '#ro',
#  'ke.',
#  '764',
#  'ler',
#  'iat',
#  'hud',
#  'oxi',
#  'era',
#  'sug',
#  '(ko',
#  'kfo',
#  'g..',
#  'rón',
#  'o-1',
#  'adf',
#  'kop',
#  'are',
#  'alp',
#  'gsa',
#  'awm',
#  '0-o',
#  'pf#',
#  'rdn',
#  'nck',
#  '#ou',
#  'ulo',
#  'ct.',
#  'tei',
#  'ggl',
#  'l-w',
#  'kic',
#  '4k#',
#  'act',
#  '#xs',
#  '615',
#  '(ho',
#  '@de',
#  '#$9',
#  'zue',
#  'bi#',
#  'snu',
#  'rsw',
#  'aq.',
#  'hz#',
#  '8.4',
#  '405',
#  '315',
#  'bir',
#  '-ho',
#  '-41',
#  '-2#',
#  'syl',
#  'maz',
#  '826',
#  'ufi',
#  'why',
#  'mpa',
#  '4.#',
#  '#p.',
#  'tt.',
#  'wre',
#  '897',
#  '(11',
#  '929',
#  'ak.',
#  'am#',
#  'vik',
#  'ctl',
#  'hoa',
#  '5.7',
#  'moi',
#  '#pn',
#  '-br',
#  'fry',
#  'edt',
#  'zur',
#  '#.2',
#  'etm',
#  'obt',
#  'aq#',
#  '-19',
#  'pic',
#  '(tw',
#  'wto',
#  'ghw',
#  '.9%',
#  'a-y',
#  'usa',
#  'onr',
#  'vau',
#  'n-t',
#  'ipw',
#  'dso',
#  'ynt',
#  '8/2',
#  'oy’',
#  '.dj',
#  'rsy',
#  '-ol',
#  'ziv',
#  'alv',
#  'nr#',
#  'erf',
#  'cgr',
#  'tou',
#  'ele',
#  'gah',
#  '#(f',
#  'dr.',
#  'unk',
#  'rpe',
#  '80s',
#  'iby',
#  'bho',
#  'rei',
#  'itu',
#  'rak',
#  'veh',
#  '#34',
#  '699',
#  'nef',
#  'n.j',
#  '389',
#  'y.u',
#  'htw',
#  'skt',
#  'guo',
#  'bar',
#  'dja',
#  '#bi',
#  're’',
#  'd-1',
#  '256',
#  'sus',
#  '09.',
#  'ad-',
#  'o/y',
#  'sep',
#  'sni',
#  'd=>',
#  'ebv',
#  'f-s',
#  'owi',
#  'n-m',
#  'dcs',
#  'gt#',
#  '7.7',
#  'oya',
#  '#ew',
#  'wi#',
#  '2yt',
#  'emu',
#  'tc.',
#  'dez',
#  'r-w',
#  'nli',
#  'fsk',
#  'kno',
#  'cai',
#  '$50',
#  'vos',
#  'mph',
#  'noc',
#  'kon',
#  'pnc',
#  'j.p',
#  'pho',
#  '#(7',
#  'ckb',
#  '9-y',
#  'ir.',
#  'nac',
#  'kyo',
#  '052',
#  'esp',
#  'occ',
#  'aiw',
#  '694',
#  'wra',
#  '8%.',
#  'krc',
#  '74t',
#  'paa',
#  '.tu',
#  'mud',
#  'iow',
#  'sub',
#  'amh',
#  '4am',
#  ').#',
#  'omb',
#  'oer',
#  'swe',
#  '1pc',
#  'awa',
#  '-be',
#  'saf',
#  'c.j',
#  '#pu',
#  '459',
#  '119',
#  'ebi',
#  'kob',
#  '#4a',
#  'f-o',
#  'ba.',
#  'anw',
#  'ghi',
#  '.op',
#  'nkl',
#  '-15',
#  'mcn',
#  '306',
#  '6.5',
#  '-du',
#  'afl',
#  'l].',
#  'ffe',
#  '.1#',
#  'rkn',
#  '+j#',
#  '#mg',
#  'sek',
#  '300',
#  '#[b',
#  'moc',
#  '#c.',
#  '390',
#  'lyn',
#  '434',
#  'e/p',
#  'fia',
#  'phl',
#  'gfu',
#  '3%)',
#  'agd',
#  'acc',
#  'geb',
#  'udu',
#  'ndb',
#  'noo',
#  'ccu',
#  '#&#',
#  '#fc',
#  '#78',
#  'stm',
#  'lfl',
#  '#$u',
#  '#26',
#  'omf',
#  '$65',
#  'hha',
#  'kam',
#  'ngo',
#  'rof',
#  's36',
#  'n22',
#  'nun',
#  'ejo',
#  'ui#',
#  '.9-',
#  '`br',
#  'ncz',
#  'f.#',
#  '#c$',
#  'gum',
#  'ubg',
#  'ia’',
#  '#fj',
#  'ued',
#  '31-',
#  'sba',
#  'uzi',
#  '2-9',
#  '$18',
#  '#57',
#  '#.c',
#  'r’s',
#  'zha',
#  '01.',
#  'osi',
#  'bam',
#  '-ta',
#  'ewd',
#  'lty',
#  'tar',
#  'y.)',
#  'xif',
#  '#14',
#  'ree',
#  'rts',
#  '$17',
#  '$23',
#  'rac',
#  '262',
#  'uic',
#  'anl',
#  'tot',
#  '979',
#  '147',
#  '628',
#  '[ia',
#  'tti',
#  'eha',
#  '#1p',
#  'hoi',
#  '/4p',
#  'jis',
#  '`on',
#  '#h.',
#  'pep',
#  'cke',
#  '45-',
#  '$24',
#  'bao',
#  'pse',
#  'cst',
#  '—de',
#  'gym',
#  'p.s',
#  'fli',
#  '.02',
#  's51',
#  'doc',
#  '-s#',
#  'bay',
#  'x.o',
#  'rix',
#  'bps',
#  'i-p',
#  'ths',
#  'bne',
#  'rtn',
#  'ga#',
#  'for',
#  'ii.',
#  'hci',
#  'ha#',
#  'a.g',
#  '#--',
#  '293',
#  '#8#',
#  'f=#',
#  'zet',
#  'fev',
#  'mt#',
#  'njo',
#  'aso',
#  'rdr',
#  'niy',
#  'eza',
#  'rox',
#  'uda',
#  'x>#',
#  'b-i',
#  'k-l',
#  '“7t',
#  'rnp',
#  'dri',
#  '20s',
#  'soh',
#  'xp#',
#  '#mt',
#  '798',
#  'ke-',
#  'won',
#  '#gy',
#  'azz',
#  'nth',
#  'iu#',
#  '#cy',
#  'zab',
#  '“sp',
#  '#lp',
#  'bn.',
#  'jiu',
#  'ca#',
#  'fo#',
#  '#sf',
#  'oa#',
#  'yn)',
#  'dae',
#  '58.',
#  'luh',
#  'yie',
#  'iag',
#  '068',
#  'oes',
#  'nb#',
#  'zol',
#  '3.4',
#  'me-',
#  'oob',
#  'nor',
#  '#nu',
#  't-g',
#  'ogn',
#  'vri',
#  '/82',
#  '#£9',
#  'ull',
#  'hp-',
#  'km#',
#  'spo',
#  'gti',
#  'npi',
#  '54#',
#  'ak#',
#  'pit',
#  'iji',
#  '#re',
#  'ddl',
#  '225',
#  'nlc',
#  'awk',
#  'hoe',
#  'kct',
#  '65-',
#  'ilp',
#  '$15',
#  '0-p',
#  '#s.',
#  '#-t',
#  'wls',
#  'atc',
#  'gen',
#  'yto',
#  '`sl',
#  'ur=',
#  'hon',
#  'ciz',
#  'fus',
#  'otz',
#  'i>#',
#  'aeu',
#  'urg',
#  'wf#',
#  'fat',
#  'ozo',
#  '-vl',
#  'ony',
#  '773',
#  'cal',
#  'g+j',
#  'ary',
#  'sp2',
#  '774',
#  'yno',
#  '$80',
#  'emo',
#  'ts]',
#  'h-e',
#  '#v#',
#  'tan',
#  'gtr',
#  '$77',
#  'hnu',
#  'dun',
#  'mdr',
#  'kar',
#  'zis',
#  'agi',
#  'chk',
#  'usn',
#  '$78',
#  'irm',
#  'yek',
#  '007',
#  '(26',
#  '(do',
#  '575',
#  '#nv',
#  'sa.',
#  '6vx',
#  '.41',
#  'aes',
#  'pow',
#  'nus',
#  '966',
#  '-si',
#  '#7%',
#  'mci',
#  '921',
#  'cas',
#  'ou#',
#  'tz#',
#  '(7-',
#  'yns',
#  'fe.',
#  'n-k',
#  '#fo',
#  'cn#',
#  '#hp',
#  '6.9',
#  'ckf',
#  '1-2',
#  'ka.',
#  'rnc',
#  'heo',
#  'omn',
#  'aur',
#  'ws.',
#  '91.',
#  'rfl',
#  '973',
#  '01s',
#  'e-r',
#  't=r',
#  '.-h',
#  'eip',
#  'ce-',
#  'j.#',
#  '214',
#  '.89',
#  '5%#',
#  'ilv',
#  'kiw',
#  'vig',
#  'pa.',
#  '-of',
#  'er.',
#  'w-a',
#  'tri',
#  'cbs',
#  '#i´',
#  '832',
#  'el.',
#  '109',
#  'l-r',
#  'idy',
#  'cp.',
#  'ils',
#  'alk',
#  'hai',
#  'raw',
#  'bs)',
#  '#s#',
#  '#tc',
#  '81s',
#  '#-1',
#  'alo',
#  'xic',
#  'hob',
#  '.h.',
#  'lm#',
#  'nuo',
#  'ko)',
#  'zal',
#  'p-o',
#  'e-y',
#  'l.n',
#  'mys',
#  '10t',
#  '360',
#  '12)',
#  '-re',
#  'ost',
#  '5.9',
#  'ran',
#  'x-d',
#  'orl',
#  's.)',
#  's3.',
#  'fa#',
#  'liv',
#  'efs',
#  'ody',
#  'vew',
#  '#ig',
#  '#be',
#  'isk',
#  '.9b',
#  'nyb',
#  'uri',
#  'tty',
#  'ss)',
#  't-u',
#  'abc',
#  '(05',
#  'iha',
#  'bit',
#  '#.5',
#  'ait',
#  'umm',
#  'ftl',
#  '#ta',
#  'ibm',
#  '8-y',
#  'nvi',
#  '910',
#  'va#',
#  '$10',
#  '00#',
#  'vt#',
#  'tgo',
#  'p.o',
#  'pro',
#  'ubr',
#  'unp',
#  'a.#',
#  '165',
#  'dra',
#  'k-u',
#  '56-',
#  'usl',
#  'lan',
#  'bot',
#  'dil',
#  'sar',
#  'ax.',
#  'sea',
#  'poo',
#  '#[h',
#  'agu',
#  'dal',
#  '-4#',
#  'r72',
#  'msi',
#  'aps',
#  'pq#',
#  'fe#',
#  '2-n',
#  '37t',
#  '#ho',
#  '4-f',
#  'voy',
#  'rsh',
#  'ibc',
#  'gia',
#  'wo-',
#  'rpu',
#  'cht',
#  '-ex',
#  '#.d',
#  'moo',
#  'erj',
#  '#<#',
#  '#oe',
#  '(ia',
#  '.t.',
#  '-zu',
#  '[th',
#  'omo',
#  '#1/',
#  'ao.',
#  'edd',
#  'deh',
#  'swo',
#  'uyr',
#  'ibo',
#  '-4)',
#  '#85',
#  'duq',
#  'acp',
#  'mpp',
#  'nsu',
#  'sah',
#  'ndn',
#  'si#',
#  'rcl',
#  'uy#',
#  'kaw',
#  'dpo',
#  'ck#',
#  '#dc',
#  '.37',
#  'ust',
#  '-as',
#  'm.p',
#  '02.',
#  'kin',
#  'is.',
#  'tb#',
#  'ayn',
#  'am]',
#  'ntm',
#  'jef',
#  '36#',
#  '40.',
#  'nfs',
#  '$6.',
#  'utb',
#  't63',
#  '137',
#  '#uv',
#  'un.',
#  '820',
#  'mam',
#  '$54',
#  '619',
#  '#le',
#  '021',
#  'nny',
#  'llf',
#  'es)',
#  're-',
#  'rav',
#  'bby',
#  'klo',
#  '-pe',
#  'ans',
#  'ctw',
#  '#ol',
#  '103',
#  '895',
#  'rzo',
#  '2h2',
#  'dt#',
#  'les',
#  '#(g',
#  'ro.',
#  'rm.',
#  '587',
#  'app',
#  'hua',
#  '50s',
#  '690',
#  'rie',
#  'jih',
#  '4-i',
#  'nev',
#  'gme',
#  'nak',
#  'alb',
#  'apf',
#  'rg-',
#  'aml',
#  'udz',
#  'uan',
#  'dig',
#  'osl',
#  'rli',
#  'abw',
#  '#yu',
#  'o-f',
#  '-li',
#  'ogy',
#  'up.',
#  'uds',
#  '857',
#  'ich',
#  'tom',
#  'cem',
#  '9-6',
#  'ven',
#  '.77',
#  'eev',
#  'd.s',
#  'any',
#  'ath',
#  '\x12s#',
#  'rif',
#  'oby',
#  'xim',
#  'emi',
#  'xt#',
#  'dim',
#  'boi',
#  'msh',
#  'wwf',
#  'lky',
#  'ads',
#  'lfr',
#  'epi',
#  'hog',
#  'gep',
#  '9.3',
#  'n.r',
#  'doh',
#  '$83',
#  'rar',
#  '#rd',
#  'cio',
#  'rdl',
#  'm.a',
#  '65g',
#  '%.#',
#  '40s',
#  'mik',
#  'c)#',
#  'dhs',
#  'ach',
#  'amp',
#  '-mp',
#  '-ux',
#  'cox',
#  'mok',
#  '23/',
#  '05#',
#  '-75',
#  'mbs',
#  'iye',
#  'biy',
#  'nwr',
#  'upg',
#  '#3%',
#  '#by',
#  'esr',
#  'oxv',
#  'ksy',
#  'w.s',
#  'd-s',
#  'dnt',
#  '-ci',
#  'chm',
#  'sna',
#  '33.',
#  'sth',
#  '55#',
#  'kr#',
#  'd-i',
#  '“ru',
#  'n27',
#  'an@',
#  'acu',
#  '-er',
#  'ulp',
#  'tas',
#  'rip',
#  '#2m',
#  'nry',
#  '3.3',
#  'nd.',
#  '.10',
#  'asu',
#  'rg#',
#  'hny',
#  'ce)',
#  'mri',
#  'eil',
#  'r-x',
#  'cea',
#  'ph.',
#  'tiu',
#  'heb',
#  's25',
#  '529',
#  '2%.',
#  '335',
#  'nom',
#  'uji',
#  'cul',
#  'fee',
#  'tts',
#  '010',
#  'pun',
#  'rgd',
#  'a-b',
#  'ndt',
#  'xom',
#  '/tu',
#  '927',
#  'unc',
#  'htl',
#  'soi',
#  'nd#',
#  'dei',
#  '#bb',
#  'ugm',
#  '4p#',
#  '-io',
#  'ak@',
#  'til',
#  'ouc',
#  'ahr',
#  'rpo',
#  'uv#',
#  'usg',
#  '-et',
#  'o-l',
#  '9.1',
#  'mf#',
#  'eu-',
#  's-c',
#  'ryb',
#  'eku',
#  '#it',
#  'gub',
#  ...]

# %%
print(len(vocab_list))
# Out:
# 10041

# %%
vocab_file='vocab_mrpc.txt'
with open(vocab_file, 'w', encoding='utf-8') as f:
    for slice in vocab_list:
        f.write(slice)
        f.write('\n')
